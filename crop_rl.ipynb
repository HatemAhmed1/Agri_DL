# %% [markdown]
# **Features:**
# The dataset contains 4800 records with 28 features (23 original features and 5 derived features), each representing critical environmental and soil parameters, along with specific crop-related metrics. These features include:
#
# **N (ppm):** Nitrogen content in the soil.
#
# **P (ppm):** Phosphorus content in the soil.
#
# **K (ppm):** Potassium content in the soil.
#
# **Temperature (°C):** Ambient temperature recorded at the farm.
#
# **Humidity (%):** Relative humidity at the location.
#
# **pH:** Soil pH level, indicating acidity or alkalinity.
#
# **Rainfall (mm):** Amount of rainfall received.
#
# **Label:** Type of crop associated with the recorded conditions (e.g., rice).
#
# **Soil Moisture (%):** Percentage of water content in the soil.
#
# **Soil Type:** Type of soil (1 = Sandy, 2 = Loamy, 3 = Clay).
#
# **Sunlight Exposure (hrs/day):** Average daily sunlight exposure.
#
# **Wind Speed (km/h):** Wind speed at the farm.
#
# **CO2 Concentration (ppm):** Carbon dioxide concentration in the air.
#
# **Organic Matter (%):** Percentage of organic material in the soil.
#
# **Irrigation Frequency (times/week):** Frequency of irrigation.
#
# **Crop Density (plants/m²):** Number of plants per square meter.
#
# **Pest Pressure (index):** Level of pest infestation.
#
# **Fertilizer Usage (kg/ha):** Amount of fertilizer applied per hectare.
#
# **Growth Stage:** Current growth stage of the crop (1 = Seedling, 2 = Vegetative, 3 = Flowering).
#
# **Urban Area Proximity (km):** Distance to the nearest urban area.
#
# **Water Source Type:** Type of water source used for irrigation (1 = River, 2 = Groundwater, 3 = Recycled).
#
# **Frost Risk (index):** Risk of frost occurrence.
#
# **Water Usage Efficiency (L/kg):** Efficiency of water usage per kilogram of crop yield.

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("Rice_data.csv")

# %%
data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label  \
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice
#
#    soil_moisture  soil_type  ...  organic_matter  irrigation_frequency  \
# 0      29.446064          2  ...        3.121395                     4
# 1      12.851183          3  ...        2.142021                     4
# 2      29.363913          2  ...        1.474974                     1
# 3      26.207732          3  ...        8.393907                     1
# 4      28.236236          2  ...        5.202285                     3
#
#    crop_density  pest_pressure  fertilizer_usage  growth_stage  \
# 0     11.743910      57.607308        188.194958             1
# 1     16.797101      74.736879         70.963629             1
# 2     12.654395       1.034478        191.976077             1
# 3     10.864360      24.091888         55.761388             3
# 4     13.852910      38.811481        185.259702             2
#
#    urban_area_proximity  water_source_type  frost_risk  water_usage_efficiency
# 0              2.719614                  3   95.649985                1.193293
# 1              4.714427                  2   77.265694                1.752672
# 2             30.431736                  2   18.192168                3.035541
# 3             10.861071                  3   82.818720                1.273341
# 4             47.190777                  3   25.466499                2.578671
#
# [5 rows x 23 columns]

# %%
data.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall  soil_moisture    soil_type  \
# count  2200.000000  2200.000000    2200.000000  2200.000000
# mean      6.469480   103.463655      20.151388     1.991364
# std       0.773938    54.958389       5.793720     0.812263
# min       3.504752    20.211267      10.024260     1.000000
# 25%       5.971693    64.551686      15.179949     1.000000
# 50%       6.425045    94.867624      20.088481     2.000000
# 75%       6.923643   124.267508      25.255146     3.000000
# max       9.935091   298.560117      29.997860     3.000000
#
#        sunlight_exposure  ...  organic_matter  irrigation_frequency  \
# count        2200.000000  ...     2200.000000           2200.000000
# mean            8.570609  ...        5.465652              3.515000
# std             1.999382  ...        2.605294              1.697912
# min             5.000710  ...        1.003338              1.000000
# 25%             6.904620  ...        3.203903              2.000000
# 50%             8.609968  ...        5.418049              4.000000
# 75%            10.220394  ...        7.686417              5.000000
# max            11.991041  ...        9.999990              6.000000
#
#        crop_density  pest_pressure  fertilizer_usage  growth_stage  \
# count   2200.000000    2200.000000       2200.000000   2200.000000
# mean      12.344959      49.850701        125.846403      1.999545
# std        4.297494      28.886354         43.564527      0.818999
# min        5.004341       0.038103         50.209990      1.000000
# 25%        8.585734      24.379866         88.030737      1.000000
# 50%       12.303616      49.982421        126.441536      2.000000
# 75%       15.975567      74.681904        163.850536      3.000000
# max       19.988474      99.983849        199.982166      3.000000
#
#        urban_area_proximity  water_source_type   frost_risk  \
# count           2200.000000        2200.000000  2200.000000
# mean              24.801013           2.003636    50.304701
# std               14.523975           0.812021    28.580352
# min                0.017756           1.000000     0.054911
# 25%               12.212594           1.000000    26.104674
# 50%               24.922548           2.000000    50.171934
# 75%               37.322761           3.000000    75.262676
# max               49.992046           3.000000    99.957274
#
#        water_usage_efficiency
# count             2200.000000
# mean                 2.990268
# std                  1.139637
# min                  1.002106
# 25%                  2.051814
# 50%                  2.968675
# 75%                  3.968736
# max                  4.997130
#
# [8 rows x 22 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   N                       2200 non-null   int64
#  1   P                       2200 non-null   int64
#  2   K                       2200 non-null   int64
#  3   temperature             2200 non-null   float64
#  4   humidity                2200 non-null   float64
#  5   ph                      2200 non-null   float64
#  6   rainfall                2200 non-null   float64
#  7   label                   2200 non-null   object
#  8   soil_moisture           2200 non-null   float64
#  9   soil_type               2200 non-null   int64
#  10  sunlight_exposure       2200 non-null   float64
#  11  wind_speed              2200 non-null   float64
#  12  co2_concentration       2200 non-null   float64
#  13  organic_matter          2200 non-null   float64
#  14  irrigation_frequency    2200 non-null   int64
#  15  crop_density            2200 non-null   float64
#  16  pest_pressure           2200 non-null   float64
#  17  fertilizer_usage        2200 non-null   float64
#  18  growth_stage            2200 non-null   int64
#  19  urban_area_proximity    2200 non-null   float64
#  20  water_source_type       2200 non-null   int64
#  21  frost_risk              2200 non-null   float64
#  22  water_usage_efficiency  2200 non-null   float64
# dtypes: float64(15), int64(7), object(1)
# memory usage: 395.4+ KB

# %%
# Dropping Label because It is Rice dataset
rice_data = data.drop(['label','urban_area_proximity','frost_risk'], axis =1)

# %%
rice_data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall  soil_moisture  \
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536      29.446064
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537      12.851183
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248      29.363913
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034      26.207732
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340      28.236236
#
#    soil_type  sunlight_exposure  wind_speed  co2_concentration  \
# 0          2           8.677355   10.109875         435.611226
# 1          3           5.754288   12.048050         401.451860
# 2          2           9.875230    9.051349         357.417963
# 3          3           8.023685    7.963606         363.694306
# 4          2           8.120512   19.264133         410.356458
#
#    organic_matter  irrigation_frequency  crop_density  pest_pressure  \
# 0        3.121395                     4     11.743910      57.607308
# 1        2.142021                     4     16.797101      74.736879
# 2        1.474974                     1     12.654395       1.034478
# 3        8.393907                     1     10.864360      24.091888
# 4        5.202285                     3     13.852910      38.811481
#
#    fertilizer_usage  growth_stage  water_source_type  water_usage_efficiency
# 0        188.194958             1                  3                1.193293
# 1         70.963629             1                  2                1.752672
# 2        191.976077             1                  2                3.035541
# 3         55.761388             3                  3                1.273341
# 4        185.259702             2                  3                2.578671

# %%
rice_data = rice_data.rename(columns={'temperature': 'T', 'humidity': 'H', 'soil_moisture': 'Soil_M', 'soil_type':'Soil_T','sunlight_exposure': 'Sun_E','wind_speed': 'W_S', 'co2_concentration':'CO2_CONC', 'organic_matter':'Organic_M','irrigation_frequency':'Irr_F','crop_density':'Crop_D', 'pest_pressure': 'Pest_Pr','fertilizer_usage':'Fert_U','growth_stage':'Growth_St','water_source_type':'Water_S','water_usage_efficiency':'Water_U_Eff'})

# %%
# Defining the States, Actions and Reward 

# State : Environmental and soil conditions 

state_col = ['T','H','ph','rainfall','Soil_M','Sun_E','W_S','CO2_CONC','Crop_D','Growth_St']

# Action : Parameter for the agent to control

action_col = ['Irr_F','Fert_U']

# Reward : Efficiency 

reward_col = ['Water_U_Eff']

# %%
# state, action, reward
state = rice_data[state_col]
action = rice_data[action_col]
reward = rice_data[reward_col]
state.head(), action.head(), reward.head()
# Out:
# (           T          H        ph    rainfall     Soil_M     Sun_E        W_S  \
#  0  20.879744  82.002744  6.502985  202.935536  29.446064  8.677355  10.109875
#  1  21.770462  80.319644  7.038096  226.655537  12.851183  5.754288  12.048050
#  2  23.004459  82.320763  7.840207  263.964248  29.363913  9.875230   9.051349
#  3  26.491096  80.158363  6.980401  242.864034  26.207732  8.023685   7.963606
#  4  20.130175  81.604873  7.628473  262.717340  28.236236  8.120512  19.264133
#
#       CO2_CONC     Crop_D  Growth_St
#  0  435.611226  11.743910          1
#  1  401.451860  16.797101          1
#  2  357.417963  12.654395          1
#  3  363.694306  10.864360          3
#  4  410.356458  13.852910          2  ,
#     Irr_F      Fert_U
#  0      4  188.194958
#  1      4   70.963629
#  2      1  191.976077
#  3      1   55.761388
#  4      3  185.259702,
#     Water_U_Eff
#  0     1.193293
#  1     1.752672
#  2     3.035541
#  3     1.273341
#  4     2.578671)

# %%
missing_values = rice_data.isnull().sum()
missing_values
# Out:
# N              0
# P              0
# K              0
# T              0
# H              0
# ph             0
# rainfall       0
# Soil_M         0
# Soil_T         0
# Sun_E          0
# W_S            0
# CO2_CONC       0
# Organic_M      0
# Irr_F          0
# Crop_D         0
# Pest_Pr        0
# Fert_U         0
# Growth_St      0
# Water_S        0
# Water_U_Eff    0
# dtype: int64

# %% [markdown]
# **State Variables:** These represent the environment and crop conditions, including:
#
# Environmental factors: temperature, humidity, rainfall, ph
#
# Soil conditions: soil_moisture, organic_matter
#
# External factors: sunlight_exposure, wind_speed, co2_concentration
#
# Crop-specific factors: crop_density, growth_stage

# %% [markdown]
# **Action Variables:** These are the variables the agent can control:
#
# irrigation_frequency: Frequency of irrigation
#
# fertilizer_usage: Amount of fertilizer applied

# %% [markdown]
# **Reward:** The agent’s goal will be to maximize water usage efficiency, which is represented by:
#
# water_usage_efficiency: This will serve as the reward for the RL agent.

# %%
# Normalize the data

from sklearn.preprocessing import MinMaxScaler

sc_state = MinMaxScaler()
sc_action = MinMaxScaler()

# Scaling 

norm_state = sc_state.fit_transform(state)
norm_action = sc_action.fit_transform(action)

# Combining the scaled values with the respective columns

norm_data = pd.DataFrame(norm_state, columns = state.columns)
norm_data[action.columns] = norm_action 

norm_data.head()

state_data = norm_data[state_col]
action_data = norm_data[action_col]

# %%
# Defining a reward threshold (above .75 is considered successful)
reward_threshold = reward.quantile(0.75)

# Display the normalized state, action, and reward threshold
reward_threshold
# Out:
# Water_U_Eff    3.968736
# Name: 0.75, dtype: float64

# %% [markdown]
# ##### Implementing Q-Learning Algorithm First

# %%
# import gym
# import numpy as np
# from gym import spaces  # Ensure this import for action and observation spaces

# import torch
# from stable_baselines3 import SAC
# from stable_baselines3.common.vec_env import DummyVecEnv
# from stable_baselines3.common.env_checker import check_env

# %%
import gym
from gym import spaces
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
class RiceEnv(gym.Env):
    def __init__(self, state_df, action_df, reward_series, reward_threshold):
        super(RiceEnv, self).__init__()

        self.state_df = state_df
        self.action_df = action_df
        self.reward_series = reward_series
        self.reward_threshold = reward_threshold
        self.current_step = 0

        # Define observation space (10 continuous variables)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(10,), dtype=np.float32)

        # Define action space as discrete with 2 actions
        self.action_space = spaces.Discrete(2)  # Assuming two discrete actions for simplicity

    def reset(self):
        self.current_step = 0
        initial_state = self.state_df.iloc[self.current_step].values
        return initial_state

    def step(self, action):
        state = self.state_df.iloc[self.current_step].values
        reward = self.reward_series.iloc[self.current_step]
        self.current_step += 1
        done = self.current_step >= len(self.state_df)

        # Get the next state or zeros if done
        next_state = self.state_df.iloc[self.current_step].values if not done else np.zeros(10)
        return next_state, reward, done, {}

# %%
def train_q_learning(env, num_episodes, learning_rate, discount_factor, exploration_rate):
    q_table = np.zeros((len(env.state_df), env.action_space.n))  # Q-table initialized to zeros

    for episode in range(num_episodes):
        state = env.reset()
        done = False

        while not done:
            current_index = env.current_step  # Store current index for Q-table access
            
            # Epsilon-greedy action selection
            if np.random.rand() < exploration_rate:
                action = env.action_space.sample()  # Explore
            else:
                action = np.argmax(q_table[current_index])  # Exploit

            next_state, reward, done, _ = env.step(action)

            # Update Q-value
            old_value = q_table[current_index, action]
            next_max = np.max(q_table[env.current_step]) if not done else 0  # Use next state index

            # Q-learning formula
            new_value = (1 - learning_rate) * old_value + learning_rate * (reward + discount_factor * next_max)
            q_table[current_index, action] = new_value

            state = next_state
        
        # Optional: Decay exploration rate
        exploration_rate = max(min_exploration_rate, exploration_rate * exploration_decay)

    return q_table

# %%
# Example usage
if __name__ == "__main__":
    # Load your datasets here
    # Example DataFrame creation (replace with your actual data)
    # Assuming norm_data is your normalized DataFrame
    # state_col = list of column names for state parameters
    # action_col = list of column names for action parameters
    # reward = Series containing rewards

    # norm_data = pd.DataFrame(...)  # Load your actual normalized data
    # state_df = norm_data[state_col]
    # action_df = norm_data[action_col]
    # reward_series = reward  # Assuming reward is a Series
    # reward_threshold = ...  # Set your reward threshold

    env = RiceEnv(norm_data[state_col], norm_data[action_col], reward, reward_threshold)

    # Hyperparameters for Q-Learning
    num_episodes = 1000
    learning_rate = 0.1
    discount_factor = 0.95
    exploration_rate = 1.0  # Start fully exploring
    exploration_decay = 0.995
    min_exploration_rate = 0.01

    # Training the Q-learning agent
    q_table = train_q_learning(env, num_episodes, learning_rate, discount_factor, exploration_rate)

    # Testing the learned policy
    state = env.reset()
    done = False
    while not done:
        action = np.argmax(q_table[env.current_step])  # Take the best action
        next_state, reward, done, _ = env.step(action)
        print(f"Action: {action}, Reward: {reward}")
        state = next_state
# Out:
# Action: 0, Reward: Water_U_Eff    1.193293
# Name: 0, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.752672
# Name: 1, dtype: float64
# Action: 0, Reward: Water_U_Eff    3.035541
# Name: 2, dtype: float64
# Action: 0, Reward: Water_U_Eff    1.273341
# Name: 3, dtype: float64
# Action: 0, Reward: Water_U_Eff    2.578671
# Name: 4, dtype: float64
# Action: 0, Reward: Water_U_Eff    1.753616
# Name: 5, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.171514
# Name: 6, dtype: float64
# Action: 0, Reward: Water_U_Eff    3.179539
# Name: 7, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.53098
# Name: 8, dtype: float64
# Action: 1, Reward: Water_U_Eff    4.586856
# Name: 9, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.476049
# Name: 10, dtype: float64
# Action: 1, Reward: Water_U_Eff    4.956311
# Name: 11, dtype: float64
# Action: 0, Reward: Water_U_Eff    1.569046
# Name: 12, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.029737
# Name: 13, dtype: float64
# Action: 0, Reward: Water_U_Eff    4.410523
# Name: 14, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.374564
# Name: 15, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.135924
# Name: 16, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.085566
# Name: 17, dtype: float64
# Action: 0, Reward: Water_U_Eff    2.290179
# Name: 18, dtype: float64
# Action: 0, Reward: Water_U_Eff    1.307594
# Name: 19, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.470109
# Name: 20, dtype: float64
# Action: 0, Reward: Water_U_Eff    3.672312
# Name: 21, dtype: float64
# Action: 0, Reward: Water_U_Eff    2.465647
# Name: 22, dtype: float64
# Action: 0, Reward: Water_U_Eff    2.686872
# Name: 23, dtype: float64
# Action: 0, Reward: Water_U_Eff    2.629314
# Name: 24, dtype: float64
# Action: 0, Reward: Water_U_Eff    3.988722
# Name: 25, dtype: float64
# Action: 1, Reward: Water_U_Eff    2.781045
# Name: 26, dtype: float64
# Action: 0, Reward: Water_U_Eff    4.596199
# Name: 27, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.169038
# Name: 28, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.457174
# Name: 29, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.667282
# Name: 30, dtype: float64
# Action: 0, Reward: Water_U_Eff    3.858349
# Name: 31, dtype: float64
# Action: 0, Reward: Water_U_Eff    1.258196
# Name: 32, dtype: float64
# Action: 0, Reward: Water_U_Eff    3.466836
# Name: 33, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.478428
# Name: 34, dtype: float64
# Action: 0, Reward: Water_U_Eff    4.937107
# Name: 35, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.867994
# Name: 36, dtype: float64
# Action: 0, Reward: Water_U_Eff    1.049514
# Name: 37, dtype: float64
# Action: 1, Reward: Water_U_Eff    2.208342
# Name: 38, dtype: float64
# Action: 1, Reward: Water_U_Eff    4.558694
# Name: 39, dtype: float64
# Action: 0, Reward: Water_U_Eff    3.60625
# Name: 40, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.08674
# Name: 41, dtype: float64
# Action: 0, Reward: Water_U_Eff    4.937216
# Name: 42, dtype: float64
# Action: 1, Reward: Water_U_Eff    4.652537
# Name: 43, dtype: float64
# Action: 0, Reward: Water_U_Eff    2.825827
# Name: 44, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.257701
# Name: 45, dtype: float64
# Action: 1, Reward: Water_U_Eff    2.243056
# Name: 46, dtype: float64
# Action: 1, Reward: Water_U_Eff    2.389992
# Name: 47, dtype: float64
# Action: 0, Reward: Water_U_Eff    2.780031
# Name: 48, dtype: float64
# Action: 1, Reward: Water_U_Eff    4.338717
# Name: 49, dtype: float64
# Action: 0, Reward: Water_U_Eff    1.179476
# Name: 50, dtype: float64
# Action: 0, Reward: Water_U_Eff    3.342658
# Name: 51, dtype: float64
# Action: 0, Reward: Water_U_Eff    3.893675
# Name: 52, dtype: float64
# Action: 0, Reward: Water_U_Eff    4.331025
# Name: 53, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.732769
# Name: 54, dtype: float64
# Action: 0, Reward: Water_U_Eff    3.656483
# Name: 55, dtype: float64
# Action: 0, Reward: Water_U_Eff    3.857388
# Name: 56, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.996545
# Name: 57, dtype: float64
# Action: 1, Reward: Water_U_Eff    4.986763
# Name: 58, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.562091
# Name: 59, dtype: float64
# Action: 0, Reward: Water_U_Eff    3.256415
# Name: 60, dtype: float64
# Action: 0, Reward: Water_U_Eff    4.562012
# Name: 61, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.167809
# Name: 62, dtype: float64
# Action: 0, Reward: Water_U_Eff    1.875338
# Name: 63, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.454028
# Name: 64, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.625788
# Name: 65, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.460022
# Name: 66, dtype: float64
# Action: 0, Reward: Water_U_Eff    4.537207
# Name: 67, dtype: float64
# Action: 0, Reward: Water_U_Eff    3.100221
# Name: 68, dtype: float64
# Action: 1, Reward: Water_U_Eff    2.538026
# Name: 69, dtype: float64
# Action: 1, Reward: Water_U_Eff    4.208631
# Name: 70, dtype: float64
# Action: 1, Reward: Water_U_Eff    2.96992
# Name: 71, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.748162
# Name: 72, dtype: float64
# Action: 1, Reward: Water_U_Eff    4.465167
# Name: 73, dtype: float64
# Action: 0, Reward: Water_U_Eff    4.561683
# Name: 74, dtype: float64
# Action: 0, Reward: Water_U_Eff    4.975014
# Name: 75, dtype: float64
# Action: 0, Reward: Water_U_Eff    3.767586
# Name: 76, dtype: float64
# Action: 1, Reward: Water_U_Eff    4.367224
# Name: 77, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.552999
# Name: 78, dtype: float64
# Action: 1, Reward: Water_U_Eff    2.510486
# Name: 79, dtype: float64
# Action: 0, Reward: Water_U_Eff    3.808248
# Name: 80, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.181773
# Name: 81, dtype: float64
# Action: 0, Reward: Water_U_Eff    4.556015
# Name: 82, dtype: float64
# Action: 0, Reward: Water_U_Eff    1.753562
# Name: 83, dtype: float64
# Action: 1, Reward: Water_U_Eff    4.843657
# Name: 84, dtype: float64
# Action: 0, Reward: Water_U_Eff    1.726006
# Name: 85, dtype: float64
# Action: 1, Reward: Water_U_Eff    4.697633
# Name: 86, dtype: float64
# Action: 0, Reward: Water_U_Eff    3.741958
# Name: 87, dtype: float64
# Action: 0, Reward: Water_U_Eff    4.349212
# Name: 88, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.166967
# Name: 89, dtype: float64
# Action: 0, Reward: Water_U_Eff    2.296473
# Name: 90, dtype: float64
# Action: 1, Reward: Water_U_Eff    2.565019
# Name: 91, dtype: float64
# Action: 1, Reward: Water_U_Eff    2.510589
# Name: 92, dtype: float64
# Action: 1, Reward: Water_U_Eff    2
dtype: float64
# Action: 0, Reward: Water_U_Eff    4.678008
# Name: 2111, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.819782
# Name: 2112, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.204346
# Name: 2113, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.584147
# Name: 2114, dtype: float64
# Action: 1, Reward: Water_U_Eff    2.503321
# Name: 2115, dtype: float64
# Action: 0, Reward: Water_U_Eff    3.904308
# Name: 2116, dtype: float64
# Action: 0, Reward: Water_U_Eff    2.596916
# Name: 2117, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.779608
# Name: 2118, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.995582
# Name: 2119, dtype: float64
# Action: 1, Reward: Water_U_Eff    2.483998
# Name: 2120, dtype: float64
# Action: 0, Reward: Water_U_Eff    1.43975
# Name: 2121, dtype: float64
# Action: 1, Reward: Water_U_Eff    4.537118
# Name: 2122, dtype: float64
# Action: 0, Reward: Water_U_Eff    2.029234
# Name: 2123, dtype: float64
# Action: 0, Reward: Water_U_Eff    4.106369
# Name: 2124, dtype: float64
# Action: 0, Reward: Water_U_Eff    1.943462
# Name: 2125, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.322777
# Name: 2126, dtype: float64
# Action: 1, Reward: Water_U_Eff    2.773014
# Name: 2127, dtype: float64
# Action: 1, Reward: Water_U_Eff    2.39267
# Name: 2128, dtype: float64
# Action: 0, Reward: Water_U_Eff    4.630534
# Name: 2129, dtype: float64
# Action: 1, Reward: Water_U_Eff    4.555296
# Name: 2130, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.516236
# Name: 2131, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.327802
# Name: 2132, dtype: float64
# Action: 1, Reward: Water_U_Eff    4.08151
# Name: 2133, dtype: float64
# Action: 0, Reward: Water_U_Eff    1.93589
# Name: 2134, dtype: float64
# Action: 0, Reward: Water_U_Eff    2.992116
# Name: 2135, dtype: float64
# Action: 0, Reward: Water_U_Eff    4.532236
# Name: 2136, dtype: float64
# Action: 1, Reward: Water_U_Eff    2.688181
# Name: 2137, dtype: float64
# Action: 0, Reward: Water_U_Eff    4.986843
# Name: 2138, dtype: float64
# Action: 1, Reward: Water_U_Eff    2.93017
# Name: 2139, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.811481
# Name: 2140, dtype: float64
# Action: 0, Reward: Water_U_Eff    1.571258
# Name: 2141, dtype: float64
# Action: 0, Reward: Water_U_Eff    3.218585
# Name: 2142, dtype: float64
# Action: 1, Reward: Water_U_Eff    4.88908
# Name: 2143, dtype: float64
# Action: 0, Reward: Water_U_Eff    1.761223
# Name: 2144, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.858409
# Name: 2145, dtype: float64
# Action: 0, Reward: Water_U_Eff    2.232463
# Name: 2146, dtype: float64
# Action: 0, Reward: Water_U_Eff    2.185037
# Name: 2147, dtype: float64
# Action: 1, Reward: Water_U_Eff    2.932989
# Name: 2148, dtype: float64
# Action: 0, Reward: Water_U_Eff    3.815821
# Name: 2149, dtype: float64
# Action: 1, Reward: Water_U_Eff    4.838866
# Name: 2150, dtype: float64
# Action: 1, Reward: Water_U_Eff    2.269833
# Name: 2151, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.483039
# Name: 2152, dtype: float64
# Action: 1, Reward: Water_U_Eff    2.116204
# Name: 2153, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.239097
# Name: 2154, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.748585
# Name: 2155, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.27508
# Name: 2156, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.78663
# Name: 2157, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.159075
# Name: 2158, dtype: float64
# Action: 0, Reward: Water_U_Eff    1.159641
# Name: 2159, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.783307
# Name: 2160, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.794379
# Name: 2161, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.529966
# Name: 2162, dtype: float64
# Action: 0, Reward: Water_U_Eff    4.177387
# Name: 2163, dtype: float64
# Action: 0, Reward: Water_U_Eff    2.090535
# Name: 2164, dtype: float64
# Action: 0, Reward: Water_U_Eff    2.697326
# Name: 2165, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.972995
# Name: 2166, dtype: float64
# Action: 0, Reward: Water_U_Eff    2.299848
# Name: 2167, dtype: float64
# Action: 0, Reward: Water_U_Eff    1.679735
# Name: 2168, dtype: float64
# Action: 0, Reward: Water_U_Eff    3.667517
# Name: 2169, dtype: float64
# Action: 0, Reward: Water_U_Eff    1.250861
# Name: 2170, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.147424
# Name: 2171, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.503331
# Name: 2172, dtype: float64
# Action: 0, Reward: Water_U_Eff    3.503006
# Name: 2173, dtype: float64
# Action: 0, Reward: Water_U_Eff    4.868037
# Name: 2174, dtype: float64
# Action: 1, Reward: Water_U_Eff    2.979209
# Name: 2175, dtype: float64
# Action: 1, Reward: Water_U_Eff    2.580128
# Name: 2176, dtype: float64
# Action: 0, Reward: Water_U_Eff    4.592643
# Name: 2177, dtype: float64
# Action: 0, Reward: Water_U_Eff    4.696974
# Name: 2178, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.589439
# Name: 2179, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.349038
# Name: 2180, dtype: float64
# Action: 0, Reward: Water_U_Eff    1.240755
# Name: 2181, dtype: float64
# Action: 0, Reward: Water_U_Eff    3.472756
# Name: 2182, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.356372
# Name: 2183, dtype: float64
# Action: 0, Reward: Water_U_Eff    4.099809
# Name: 2184, dtype: float64
# Action: 0, Reward: Water_U_Eff    3.464876
# Name: 2185, dtype: float64
# Action: 1, Reward: Water_U_Eff    3.181558
# Name: 2186, dtype: float64
# Action: 0, Reward: Water_U_Eff    2.0493
# Name: 2187, dtype: float64
# Action: 1, Reward: Water_U_Eff    2.804276
# Name: 2188, dtype: float64
# Action: 1, Reward: Water_U_Eff    2.673302
# Name: 2189, dtype: float64
# Action: 1, Reward: Water_U_Eff    1.861332
# Name: 2190, dtype: float64
# Action: 0, Reward: Water_U_Eff    4.132128
# Name: 2191, dtype: float64
# Action: 0, Reward: Water_U_Eff    4.564781
# Name: 2192, dtype: float64
# Action: 0, Reward: Water_U_Eff    1.988662
# Name: 2193, dtype: float64
# Action: 0, Reward: Water_U_Eff    1.183792
# Name: 2194, dtype: float64
# Action: 0, Reward: Water_U_Eff    4.111619
# Name: 2195, dtype: float64
# Action: 0, Reward: Water_U_Eff    4.190796
# Name: 2196, dtype: float64
# Action: 1, Reward: Water_U_Eff    2.44701
# Name: 2197, dtype: float64
# Action: 1, Reward: Water_U_Eff    4.119388
# Name: 2198, dtype: float64
# Action: 1, Reward: Water_U_Eff    2.758819
# Name: 2199, dtype: float64

# %%
import pickle

# Assume q_table is the trained Q-table
# Saving the Q-table to a file
with open('q_table.pkl', 'wb') as file:
    pickle.dump(q_table, file)

# %%
import pickle
# Loading the Q-table from the file
with open('q_table.pkl', 'rb') as file:
    q_table = pickle.load(file)

# Now q_table can be used without retraining

# %%
norm_data[state_col]
# Out:
#              T         H        ph  rainfall    Soil_M     Sun_E       W_S  \
# 0     0.345886  0.790267  0.466264  0.656458  0.972374  0.525962  0.505643
# 1     0.371445  0.770633  0.549480  0.741675  0.141533  0.107803  0.602608
# 2     0.406854  0.793977  0.674219  0.875710  0.968261  0.697323  0.452686
# 3     0.506901  0.768751  0.540508  0.799905  0.810243  0.432451  0.398267
# 4     0.324378  0.785626  0.641291  0.871231  0.911802  0.446302  0.963621
# ...        ...       ...       ...       ...       ...       ...       ...
# 2195  0.515037  0.608410  0.509353  0.566064  0.033719  0.762505  0.960030
# 2196  0.533473  0.494359  0.401561  0.386972  0.109123  0.153047  0.530334
# 2197  0.439202  0.617880  0.444433  0.550071  0.949499  0.872129  0.692358
# 2198  0.500627  0.441760  0.506045  0.384280  0.181141  0.442987  0.827227
# 2199  0.424029  0.538222  0.509317  0.433721  0.695291  0.520581  0.724364
#
#       CO2_CONC    Crop_D  Growth_St
# 0     0.856244  0.449780        0.0
# 1     0.514592  0.787017        0.0
# 2     0.074178  0.510544        0.0
# 3     0.136952  0.391082        1.0
# 4     0.603653  0.590529        0.5
# ...        ...       ...        ...
# 2195  0.890928  0.907154        1.0
# 2196  0.552675  0.694978        0.5
# 2197  0.104830  0.530717        0.5
# 2198  0.655241  0.791757        0.5
# 2199  0.631331  0.643867        1.0
#
# [2200 rows x 10 columns]

# %%
# Initialize storage for RL results (simulated reduced usage)
reduced_water_usage = []
reduced_fertilizer_usage = []

# Reset the environment
state = env.reset()
done = False

# Ensure current_step doesn't exceed the number of rows in norm_data
while not done and env.current_step < len(norm_data):
    # Select the action with the highest Q-value for the current state
    action = np.argmax(q_table[env.current_step])
    
    # Get the next state and reward
    next_state, reward, done, _ = env.step(action)
    
    # Ensure that env.current_step does not exceed the dataset length
    if env.current_step < len(norm_data):
        # Action 0 corresponds to reducing water usage (Irr_F), Action 1 corresponds to reducing fertilizer usage (Fert_U)
        if action == 0:
            # Simulate reduced water usage based on current irrigation frequency (20% reduction)
            reduced_water_usage.append(action_data.iloc[env.current_step]['Irr_F'] * 0.8)
            reduced_fertilizer_usage.append(action_data.iloc[env.current_step]['Fert_U'])  # No reduction in fertilizer usage
        elif action == 1:
            # Simulate reduced fertilizer usage (20% reduction)
            reduced_fertilizer_usage.append(action_data.iloc[env.current_step]['Fert_U'] * 0.8)
            reduced_water_usage.append(action_data.iloc[env.current_step]['Irr_F'])  # No reduction in water usage
    
    # Move to the next state
    state = next_state

# Convert lists to NumPy arrays for further processing
reduced_water_usage = np.array(reduced_water_usage)
reduced_fertilizer_usage = np.array(reduced_fertilizer_usage)

# Plotting the results: Initial vs Reduced Usage

# Plotting initial vs reduced water usage
plt.figure(figsize=(10, 6))

plt.subplot(2, 1, 1)
plt.plot(action_data['Irr_F'], label='Initial Water Usage')
plt.plot(reduced_water_usage, label='Reduced Water Usage (RL)', linestyle='--')
plt.title('Water Usage Before and After RL Optimization')
plt.ylabel('Irrigation Frequency')
plt.legend()

# Plotting initial vs reduced fertilizer usage
plt.subplot(2, 1, 2)
plt.plot(action_data['Fert_U'], label='Initial Fertilizer Usage')
plt.plot(reduced_fertilizer_usage, label='Reduced Fertilizer Usage (RL)', linestyle='--')
plt.title('Fertilizer Usage Before and After RL Optimization')
plt.ylabel('Fertilizer Usage')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate cost reduction
water_cost_per_unit = 0.5  # Assumed cost per unit of water
fertilizer_cost_per_unit = 1.2  # Assumed cost per unit of fertilizer

initial_water_usage = rice_data['Irr_F'] * rice_data['Water_U_Eff']
initial_fertilizer_usage = rice_data['Fert_U']
initial_total_cost = (initial_water_usage * water_cost_per_unit) + (initial_fertilizer_usage * fertilizer_cost_per_unit)

# Simulate reduced water and fertilizer usage (replace this with real RL results)
reduced_water_usage = initial_water_usage * np.random.uniform(0.7, 0.9, size=len(initial_water_usage))  # 10-30% reduction
reduced_fertilizer_usage = initial_fertilizer_usage * np.random.uniform(0.7, 0.9, size=len(initial_fertilizer_usage))

# Calculate reduced total cost
reduced_total_cost = (reduced_water_usage * water_cost_per_unit) + (reduced_fertilizer_usage * fertilizer_cost_per_unit)

# Cost reduction
cost_reduction = initial_total_cost - reduced_total_cost

# Visualization
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(initial_total_cost, bins=30, alpha=0.7, label='Before RL', color='blue')
plt.hist(reduced_total_cost, bins=30, alpha=0.7, label='After RL', color='green')
plt.title('Total Cost: Before vs After RL')
plt.xlabel('Cost')
plt.ylabel('Frequency')
plt.legend()

plt.subplot(1, 2, 2)
plt.hist(cost_reduction, bins=30, color='orange', alpha=0.7)
plt.title('Cost Reduction Distribution After RL')
plt.xlabel('Cost Reduction')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# # Visualizing Water Usage Efficiency Over Time
# plt.figure(figsize=(10, 5))
# plt.plot(norm_data.index, norm_data['Water_U_Eff'], label='Water Usage Efficiency', color='blue')
# plt.title('Water Usage Efficiency Over Time')
# plt.xlabel('Time (Episodes)')
# plt.ylabel('Efficiency')
# plt.legend()
# plt.show()

# %%
# Plotting Irrigation Frequency and Fertilizer Usage Over Time
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(norm_data.index, norm_data['Irr_F'], label='Irrigation Frequency', color='green')
plt.title('Irrigation Frequency Over Time')
plt.xlabel('Time (Episodes)')
plt.ylabel('Irrigation Frequency')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(norm_data.index, norm_data['Fert_U'], label='Fertilizer Usage', color='orange')
plt.title('Fertilizer Usage Over Time')
plt.xlabel('Time (Episodes)')
plt.ylabel('Fertilizer Usage')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Cumulative Reward Plot
cumulative_reward = np.cumsum(reward.values)

plt.figure(figsize=(10, 5))
plt.plot(norm_data.index, cumulative_reward, label='Cumulative Reward', color='purple')
plt.title('Cumulative Reward Over Time')
plt.xlabel('Time (Episodes)')
plt.ylabel('Cumulative Reward')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 5
#       2 cumulative_reward = np.cumsum(reward.values)
#       4 plt.figure(figsize=(10, 5))
# ----> 5 plt.plot(norm_data.index, cumulative_reward, label='Cumulative Reward', color='purple')
#       6 plt.title('Cumulative Reward Over Time')
#       7 plt.xlabel('Time (Episodes)')
#
# File c:\Users\Hatem Abdul Hakeem\Desktop\final-year\.venv\lib\site-packages\matplotlib\pyplot.py:2840, in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# File c:\Users\Hatem Abdul Hakeem\Desktop\final-year\.venv\lib\site-packages\matplotlib\axes\_axes.py:1743, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1512 """
#    1513 Plot y versus x as lines and/or markers.
#    1514
#    (...)
#    1740 (``'green'``) or hex strings (``'#008000'``).
#    1741 """
#    1742 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744 for line in lines:
#    1745     self.add_line(line)
#
# File c:\Users\Hatem Abdul Hakeem\Desktop\final-year\.venv\lib\site-packages\matplotlib\axes\_base.py:273, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     271     this += args[0],
#     272     args = args[1:]
# --> 273 yield from self._plot_args(this, kwargs)
#
# File c:\Users\Hatem Abdul Hakeem\Desktop\final-year\.venv\lib\site-packages\matplotlib\axes\_base.py:399, in _process_plot_var_args._plot_args(self, tup, kwargs)
#     396     self.axes.yaxis.update_units(y)
#     398 if x.shape[0] != y.shape[0]:
# --> 399     raise ValueError(f"x and y must have same first dimension, but "
#     400                      f"have shapes {x.shape} and {y.shape}")
#     401 if x.ndim > 2 or y.ndim > 2:
#     402     raise ValueError(f"x and y can be no greater than 2-D, but have "
#     403                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (2200,) and (1,)

# %%
from mpl_toolkits.mplot3d import Axes3D

# 3D State Transitions Visualization
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(norm_data['T'], norm_data['Soil_M'], norm_data['Sun_E'], c='r', marker='o')
ax.set_xlabel('Temperature')
ax.set_ylabel('Soil Moisture')
ax.set_zlabel('Sunlight Exposure')

plt.title('3D Visualization of Environmental States')
plt.show()

# %%
# Plotting Cost Breakdown (Water vs Fertilizer) Before and After RL

# Assuming we have total costs calculated (water + fertilizer)
norm_data['Water_Cost'] = norm_data['Irr_F'] * 0.5  # Hypothetical cost formula
norm_data['Fertilizer_Cost'] = norm_data['Fert_U'] * 0.5

# Summing up costs before RL and after RL (just a random threshold for demonstration)
before_rl = norm_data.iloc[:int(0.5 * len(norm_data))]
after_rl = norm_data.iloc[int(0.5 * len(norm_data)):]

before_cost = before_rl[['Water_Cost', 'Fertilizer_Cost']].sum()
after_cost = after_rl[['Water_Cost', 'Fertilizer_Cost']].sum()

# Bar plot
labels = ['Water Cost', 'Fertilizer Cost']
before = [before_cost['Water_Cost'], before_cost['Fertilizer_Cost']]
after = [after_cost['Water_Cost'], after_cost['Fertilizer_Cost']]

x = np.arange(len(labels))  # label locations
width = 0.35  # bar width

fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x - width/2, before, width, label='Before RL')
rects2 = ax.bar(x + width/2, after, width, label='After RL')

ax.set_ylabel('Cost')
ax.set_title('Cost Breakdown: Water vs Fertilizer')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

plt.show()

# %%
# Plotting Crop Growth Stages Over Time
plt.figure(figsize=(10, 5))
plt.plot(norm_data.index, norm_data['Growth_St'], label='Crop Growth Stage', color='brown')
plt.title('Crop Growth Stages Over Time')
plt.xlabel('Time (Episodes)')
plt.ylabel('Growth Stage')
plt.legend()
plt.show()

# %%
# Plotting Soil Moisture Levels Over Time
plt.figure(figsize=(10, 5))
plt.plot(norm_data.index, norm_data['Soil_M'], label='Soil Moisture', color='blue')
plt.title('Soil Moisture Levels Over Time')
plt.xlabel('Time (Episodes)')
plt.ylabel('Soil Moisture')
plt.legend()
plt.show()

# %%
import seaborn as sns

# Example heatmap to show frequency of actions taken by the agent
# Assuming we have 'action' DataFrame representing Irrigation and Fertilizer action choices (0 or 1)
action_frequency = pd.DataFrame({
    'Irr_F_Frequency': action_data['Irr_F'].value_counts(),
    'Fert_U_Frequency': action_data['Fert_U'].value_counts()
})

# Plotting heatmap of the agent's action frequencies
plt.figure(figsize=(8, 6))
sns.heatmap(action_frequency, annot=True, cmap="Blues")
plt.title('Agent Action Frequency: Irrigation and Fertilizer')
plt.show()

# %%
# Plotting CO2 Concentration Over Time
plt.figure(figsize=(10, 5))
plt.plot(norm_data.index, norm_data['CO2_CONC'], label='CO2 Concentration', color='red')
plt.title('CO2 Concentration Over Time')
plt.xlabel('Time (Episodes)')
plt.ylabel('CO2 Concentration')
plt.legend()
plt.show()

# %%
# class RiceEnv(gym.Env):
#     def __init__(self, state_df, action_df, reward_series, reward_threshold):
#         super(RiceEnv, self).__init__()

#         self.state_df = state_df
#         self.action_df = action_df
#         self.reward_series = reward_series
#         self.reward_threshold = reward_threshold
#         self.current_step = 0

#         # Define observation space (10 continuous variables between 0 and 1)
#         self.observation_space = spaces.Box(low=0.0, high=1.0, shape=(10,), dtype=np.float32)

#         # Define action space as continuous with 4 actions
#         self.action_space = spaces.Box(low=-1.0, high=1.0, shape=(4,), dtype=np.float32)

#     def reset(self, seed=None, options=None):
#         super().reset(seed=seed)
#         self.current_step = 0

#         # Generate initial state (between 0 and 1)
#         initial_state = np.random.uniform(0, 1, size=(10,))

#         # Debug: Print before clipping
#         print(f"Initial state before clipping: {initial_state}")

#         # Clip the initial state to ensure it lies within the observation space bounds
#         initial_state = np.clip(initial_state, self.observation_space.low, self.observation_space.high)

#         # Debug: Print after clipping
#         print(f"Initial state after clipping: {initial_state}")
#         print(f"Observation space low: {self.observation_space.low}")
#         print(f"Observation space high: {self.observation_space.high}")

#         # Final check: Ensure the initial state is within bounds using a tolerance
#         assert np.allclose(initial_state, np.clip(initial_state, self.observation_space.low, self.observation_space.high), atol=1e-6), \
#             f"Initial state is still out of bounds after clipping: {initial_state}"

#         return initial_state  # OpenAI Gym expects only the observation

#     def step(self, action):
#         # Get the current state
#         state = np.array(self.state_df.iloc[self.current_step])

#         # Reward calculation based on water usage efficiency
#         reward = self.reward_series.iloc[self.current_step]
#         if reward < self.reward_threshold:
#             reward -= (self.reward_threshold - reward)

#         # Move to the next step
#         self.current_step += 1
#         done = self.current_step >= len(self.state_df)

#         # Get the next state or zeros if done
#         next_state = np.array(self.state_df.iloc[self.current_step]) if not done else np.zeros_like(state)

#         # Clip the next state to ensure it lies within the observation space bounds
#         next_state = np.clip(next_state, self.observation_space.low, self.observation_space.high)

#         # Final check: Ensure the next state is within bounds using a tolerance
#         assert np.allclose(next_state, np.clip(next_state, self.observation_space.low, self.observation_space.high), atol=1e-6), \
#             f"Next state is still out of bounds after clipping: {next_state}"

#         return next_state, reward, done, {}  # OpenAI Gym expects (obs, reward, done, info)

#     def render(self, mode='human'):
#         pass

# %%
# import gym
# from gym import spaces
# import numpy as np
# import pandas as pd

# class RiceEnv(gym.Env):
#     def __init__(self, state_df, action_df, reward_series, reward_threshold):
#         super(RiceEnv, self).__init__()

#         self.state_df = state_df
#         self.action_df = action_df
#         self.reward_series = reward_series
#         self.reward_threshold = reward_threshold
#         self.current_step = 0

#         # Define observation space (10 continuous variables)
#         self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(10,), dtype=np.float32)

#         # Define action space as continuous with 2 actions
#         self.action_space = spaces.Box(low=-1.0, high=1.0, shape=(2,), dtype=np.float32)

#     def reset(self, options=None):
#         super().reset()
#         self.current_step = 0

#         # Get initial state
#         initial_state = self.state_df.iloc[self.current_step].values  # Assuming 10 state parameters

#         # Debug: Print initial state
#         print(f"Initial state: {initial_state}")

#         return initial_state  # OpenAI Gym expects only the observation

#     def step(self, action):
#         # Get the current state
#         state = self.state_df.iloc[self.current_step].values  # State parameters
#         reward = self.reward_series.iloc[self.current_step]  # Reward parameter

#         # Move to the next step
#         self.current_step += 1
#         done = self.current_step >= len(self.state_df)

#         # Get the next state or zeros if done
#         next_state = self.state_df.iloc[self.current_step].values if not done else np.zeros(10)

#         return next_state, reward, done, {}  # OpenAI Gym expects (obs, reward, done, info)

#     def render(self, mode='human'):
#         pass

# %%
# from stable_baselines3 import SAC

# # Create the environment
# env = RiceEnv(norm_data[state_col], norm_data[action_col], reward, reward_threshold)

# # Define the model using SAC
# model = SAC('MlpPolicy', env, verbose=1)

# # Train the model
# model.learn(total_timesteps=100000)

# # Evaluate or test the model
# obs = env.reset()
# for _ in range(1000):
#     action, _states = model.predict(obs, deterministic=True)  # Added deterministic for clarity
#     obs, reward, done, info = env.step(action)
#     if done:
#         obs = env.reset()

# %%
# from stable_baselines3 import SAC
# from stable_baselines3.common.vec_env import DummyVecEnv
# from stable_baselines3.common.monitor import Monitor

# # Create your environment
# env = RiceEnv(norm_data[state_col],norm_data[action_col],reward, reward_threshold)
# env = Monitor(env)  # Wrap with Monitor
# env = DummyVecEnv([lambda: env])  # Wrap with DummyVecEnv

# model = SAC('MlpPolicy', env, verbose=1)

# # Train the model
# #

# %%
# # Clip the state_df in the environment to make sure all values are in [0, 1]
# norm_data[state_col] = np.clip(norm_data[state_col], 0, 1)

# # # Now, re-instantiate the environment and test the reset function again
# # env = RiceEnv(norm_data[state_col], norm_data[action_col], reward, reward_threshold)

# # # Check the environment
# # check_env(env)

# # # Test the reset function
# # obs = env.reset()

# # # Debugging print: observation returned by reset and the observation space
# # print("Observation returned by reset():", obs)
# # print("Observation space:", env.observation_space)

# %%
# # Clip the state_df in the environment to make sure all values are in [0, 1]
# norm_data[state_col] = np.clip(norm_data[state_col], 0, 1)

# %%
# # Print the state data before normalization
# print("State data before normalization:\n", norm_data[state_col].head())

# # Ensure normalization between 0 and 1
# min_vals = norm_data[state_col].min()
# max_vals = norm_data[state_col].max()

# # Apply normalization: (value - min) / (max - min)
# norm_data[state_col] = (norm_data[state_col] - min_vals) / (max_vals - min_vals)

# # Print state data after normalization
# print("State data after normalization:\n", norm_data[state_col].head())

# # Check if any values are still out of bounds after normalization
# out_of_bounds_low = (norm_data[state_col] < 0).any().any()  # Checks if any values are less than 0
# out_of_bounds_high = (norm_data[state_col] > 1).any().any()  # Checks if any values are greater than 1



# if out_of_bounds_low or out_of_bounds_high:
#     print("Warning: Some values are still out of bounds after normalization!")
# else:
#     print("All values are within bounds after normalization.")
